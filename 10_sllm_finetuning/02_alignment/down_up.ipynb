# %%
# huggingface 다운로드 및 업로드
from huggingface_hub import snapshot_download, upload_folder
from dotenv import load_dotenv
import os

load_dotenv()
os.environ['HF_TOKEN'] = os.getenv("HF_TOKEN")

upload_folder(
    folder_path=snapshot_download("capybaraOh/vclm-korean-7b-orca-math-korean-dpo"),
    repo_id="너아이디/vclm-korean-7b-orca-math-korean-dpo"
)
